# %%
# The bottom library is used to create connection between the docker postgresql database and the code for the chatbot this is test environment

# %%
pip install psycopg2-binary
# Out:
# Collecting psycopg2-binary
#   Downloading psycopg2_binary-2.9.11-cp310-cp310-win_amd64.whl.metadata (5.1 kB)
# Downloading psycopg2_binary-2.9.11-cp310-cp310-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ------------------------------ --------- 2.1/2.7 MB 13.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 13.1 MB/s  0:00:00
# Installing collected packages: psycopg2-binary
# Successfully installed psycopg2-binary-2.9.11
# Note: you may need to restart the kernel to use updated packages.

# %%
import socket
print(socket.gethostbyname("localhost"))
# Out:
# 127.0.0.1

# %%
#This is where the connection is happening with docker before this i had installed postgresql on my windows which I disabled and then this was
#working fine

# %%
import psycopg2

conn = psycopg2.connect(
    host="localhost",
    port=5432,
    database="chatbot_test",
    user="postgres",
    password="postgres"
)

cursor = conn.cursor()
cursor.execute("SELECT version();")
print(cursor.fetchone())

cursor.close()
conn.close()
# Out:
# ('PostgreSQL 16.12 (Debian 16.12-1.pgdg12+1) on x86_64-pc-linux-gnu, compiled by gcc (Debian 12.2.0-14+deb12u1) 12.2.0, 64-bit',)

# %%
from sentence_transformers import SentenceTransformer
import numpy as np
import psycopg2
import uuid

# Load embedding model
model = SentenceTransformer("all-MiniLM-L6-v2")

# Sample text
text = "Ideam provides engineering and innovation services."

# Generate embedding
embedding = model.encode(text).tolist()

# Connect to DB
conn = psycopg2.connect(
    host="localhost",
    port=5432,
    database="chatbot_test",
    user="postgres",
    password="postgres"
)

cursor = conn.cursor()

# Insert into knowledge_base
cursor.execute(
    """
    INSERT INTO knowledge_base (id, content, embedding)
    VALUES (%s, %s, %s)
    """,
    (str(uuid.uuid4()), text, embedding)
)

conn.commit()
cursor.close()
conn.close()

print("Inserted successfully")
# Out:
# Inserted successfully

# %%
### This code here is to check the sql table created

# %%
import pandas as pd
import psycopg2

conn = psycopg2.connect(
    host="localhost",
    port=5432,
    database="chatbot_test",
    user="postgres",
    password="postgres"
)

query = """
SELECT * FROM knowledge_base;
"""
#df_full = pd.read_sql("SELECT * FROM knowledge_base;", conn)
#df_full

df = pd.read_sql(query, conn)
conn.close()

df
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8016\3470638943.py:18: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
#                                      id  \
# 0  b170470c-8ad6-43d1-98fa-fc018162af81
#
#                                              content  \
# 0  Ideam provides engineering and innovation serv...
#
#                                            embedding  \
# 0  [-0.0218644,-0.08375201,0.021609046,-0.0477073...
#
#                   created_at
# 0 2026-02-25 10:44:09.868022

# %%
## this code below is to check the cosine similarity using pgvector closer to 0 much similar far from 0 less similar

# %%
import psycopg2
from sentence_transformers import SentenceTransformer

# Load model
model = SentenceTransformer("all-MiniLM-L6-v2")

# Question to test
query_text = "What services does Ideam provide?"

# Generate embedding
query_embedding = model.encode(query_text).tolist()

# Connect to DB
conn = psycopg2.connect(
    host="localhost",
    port=5432,
    database="chatbot_test",
    user="postgres",
    password="postgres"
)

cursor = conn.cursor()

# Similarity search
cursor.execute("""
    SELECT content,
           embedding <=> %s::vector AS distance
    FROM knowledge_base
    ORDER BY embedding <=> %s::vector
    LIMIT 3;
""", (query_embedding, query_embedding))

results = cursor.fetchall()
results
cursor.close()
conn.close()

results
# Out:
# [('Ideam provides engineering and innovation services.', 0.18838050400076467)]

# %%
def retrieve_top_k(query_text, k=3):
    from sentence_transformers import SentenceTransformer
    import psycopg2

    model = SentenceTransformer("all-MiniLM-L6-v2")
    query_embedding = model.encode(query_text).tolist()

    conn = psycopg2.connect(
        host="localhost",
        port=5432,
        database="chatbot_test",
        user="postgres",
        password="postgres"
    )

    cursor = conn.cursor()

    cursor.execute("""
        SELECT content,
               embedding <=> %s::vector AS distance
        FROM knowledge_base
        ORDER BY embedding <=> %s::vector
        LIMIT %s;
    """, (query_embedding, query_embedding, k))

    results = cursor.fetchall()

    cursor.close()
    conn.close()

    return results

# %%
retrieve_top_k("What services does Ideam offer?")
# Out:
# [('Ideam provides engineering and innovation services.', 0.21245839558665447)]

# %%
#### the below code is for testing the file structure we have now

# %%
import sys
import os

# Get project root (one level above notebooks/)
project_root = os.path.abspath("..")
sys.path.append(project_root)

print("Project root added:", project_root)
# Out:
# Project root added: C:\Users\user\chatbot_postgresql_test

# %%
from app.embeddings.embedder import get_embedding
from app.database.connection import get_connection

print(get_embedding("Test sentence")[:5])

conn = get_connection()
print("Connection successful")
conn.close()
# Out:
# [0.04297280311584473, 0.09663485735654831, -0.0021291545126587152, 0.07826830446720123, -0.006417464464902878]
# Connection successful

# %%
## checking Rag Connection ######

# %%
from app.embeddings.embedder import get_embedding
from app.rag.retriever import retrieve_similar

query = "What services does Ideam offer?"
embedding = get_embedding(query)

results = retrieve_similar(embedding)

results
# Out:
# [('Ideam provides engineering and innovation services.', 0.21245839558665447)]

# %%
### this code block is to test the LLM and chat code

# %%
from app.chat.chat_service import process_query

response = process_query("What services does Ideam provide?")

response
# Out:
# config.json:   0%|          | 0.00/735 [00:00<?, ?B/s]
# C:\Users\user\anaconda3\envs\chatbot\lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\user\.cache\huggingface\hub\models--microsoft--phi-2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/564M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/99.0 [00:00<?, ?B/s]
# Device set to use cuda:0
# {'answer': None,
#  'retrieved_docs': [('Ideam provides engineering and innovation services.',
#    0.18838050400076467)]}

# %%
### Here we are testing the new model that we have used

# %%
from transformers import pipeline
import torch

generator = pipeline(
    "text-generation",
    model="microsoft/phi-2",
    device=0 if torch.cuda.is_available() else -1
)

prompt = """
Answer clearly:

Question: What services does Ideam provide?
Answer:
"""

output = generator(prompt, max_new_tokens=100)

print(output[0]["generated_text"])
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Device set to use cuda:0
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[3], line 4
#       1 from transformers import pipeline
#       2 import torch
# ----> 4 generator = pipeline(
#       5     "text-generation",
#       6     model="microsoft/phi-2",
#       7     device=0 if torch.cuda.is_available() else -1
#       8 )
#      10 prompt = """
#      11 Answer clearly:
#      12
#      13 Question: What services does Ideam provide?
#      14 Answer:
#      15 """
#      17 output = generator(prompt, max_new_tokens=100)
#
# File ~\anaconda3\envs\chatbot\lib\site-packages\transformers\pipelines\__init__.py:1229, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, processor, framework, revision, use_fast, token, device, device_map, dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#    1226 if processor is not None:
#    1227     kwargs["processor"] = processor
# -> 1229 return pipeline_class(model=model, framework=framework, task=task, **kwargs)
#
# File ~\anaconda3\envs\chatbot\lib\site-packages\transformers\pipelines\text_generation.py:121, in TextGenerationPipeline.__init__(self, *args, **kwargs)
#     120 def __init__(self, *args, **kwargs):
# --> 121     super().__init__(*args, **kwargs)
#     122     self.check_model_type(
#     123         TF_MODEL_FOR_CAUSAL_LM_MAPPING_NAMES if self.framework == "tf" else MODEL_FOR_CAUSAL_LM_MAPPING_NAMES
#     124     )
#     125     if "prefix" not in self._preprocess_params:
#     126         # This is very specific. The logic is quite complex and needs to be done
#     127         # as a "default".
#     128         # It also defines both some preprocess_kwargs and generate_kwargs
#     129         # which is why we cannot put them in their respective methods.
#
# File ~\anaconda3\envs\chatbot\lib\site-packages\transformers\pipelines\base.py:1044, in Pipeline.__init__(self, model, tokenizer, feature_extractor, image_processor, processor, modelcard, framework, task, device, binary_output, **kwargs)
#    1037 # We shouldn't call `model.to()` for models loaded with accelerate as well as the case that model is already on device
#    1038 if (
#    1039     self.framework == "pt"
#    1040     and self.model.device != self.device
#    1041     and not (isinstance(self.device, int) and self.device < 0)
#    1042     and hf_device_map is None
#    1043 ):
# -> 1044     self.model.to(self.device)
#    1046 # If it's a generation pipeline and the model can generate:
#    1047 # 1 - create a local generation config. This is done to avoid side-effects on the model as we apply local
#    1048 # tweaks to the generation config.
#    1049 # 2 - load the assistant model if it is passed.
#    1050 if self._pipeline_calls_generate and self.model.can_generate():
#
# File ~\anaconda3\envs\chatbot\lib\site-packages\transformers\modeling_utils.py:4343, in PreTrainedModel.to(self, *args, **kwargs)
#    4338     if dtype_present_in_args:
#    4339         raise ValueError(
#    4340             "You cannot cast a GPTQ model in a new `dtype`. Make sure to load the model using `from_pretrained` using the desired"
#    4341             " `dtype` by passing the correct `dtype` argument."
#    4342         )
# -> 4343 return super().to(*args, **kwargs)
#
# File ~\anaconda3\envs\chatbot\lib\site-packages\torch\nn\modules\module.py:1344, in Module.to(self, *args, **kwargs)
#    1341         else:
#    1342             raise
# -> 1344 return self._apply(convert)
#
# File ~\anaconda3\envs\chatbot\lib\site-packages\torch\nn\modules\module.py:904, in Module._apply(self, fn, recurse)
#     902 if recurse:
#     903     for module in self.children():
# --> 904         module._apply(fn)
#     906 def compute_should_use_set_data(tensor, tensor_applied):
#     907     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     908         # If the new tensor has compatible tensor type as the existing tensor,
#     909         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     914         # global flag to let the user control whether they want the future
#     915         # behavior of overwriting the existing tensor or not.
#
# File ~\anaconda3\envs\chatbot\lib\site-packages\torch\nn\modules\module.py:931, in Module._apply(self, fn, recurse)
#     927 # Tensors stored in modules are graph leaves, and we don't want to
#     928 # track autograd history of `param_applied`, so we have to use
#     929 # `with torch.no_grad():`
#     930 with torch.no_grad():
# --> 931     param_applied = fn(param)
#     932 p_should_use_set_data = compute_should_use_set_data(param, param_applied)
#     934 # subclasses may have multiple child tensors so we need to use swap_tensors
#
# File ~\anaconda3\envs\chatbot\lib\site-packages\torch\nn\modules\module.py:1330, in Module.to.<locals>.convert(t)
#    1323     if convert_to_format is not None and t.dim() in (4, 5):
#    1324         return t.to(
#    1325             device,
#    1326             dtype if t.is_floating_point() or t.is_complex() else None,
#    1327             non_blocking,
#    1328             memory_format=convert_to_format,
#    1329         )
# -> 1330     return t.to(
#    1331         device,
#    1332         dtype if t.is_floating_point() or t.is_complex() else None,
#    1333         non_blocking,
#    1334     )
#    1335 except NotImplementedError as e:
#    1336     if str(e) == "Cannot copy out of meta tensor; no data!":
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 250.00 MiB. GPU 0 has a total capacity of 4.00 GiB of which 0 bytes is free. Of the allocated memory 10.20 GiB is allocated by PyTorch, and 391.67 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
import sys
import os

# Force project root into Python path
PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), "."))

if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

print("Using project root:", PROJECT_ROOT)
# Out:
# Using project root: C:\Users\user\chatbot_postgresql_test

# %%
from app.chat.chat_service import process_query

process_query("What services does IDEAM provide?")
# Out:
# Device set to use cuda:0
# Token indices sequence length is longer than the specified maximum sequence length for this model (587 > 512). Running this sequence through the model will result in indexing errors
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# {'answer': 'expert support in data analytics, biotechnology, and environmental science.'}

# %%
##### run this for gradio

# %%
import gradio as gr
import uuid
from app.chat.chat_service import process_query

session_id = str(uuid.uuid4())

def chat(message):
    result = process_query(message, debug=True, session_id=session_id)
    return result["answer"], result["retrieved_docs"]

with gr.Blocks() as demo:
    gr.Markdown("# IDEAM Dev Chatbot")

    input_box = gr.Textbox(label="Ask IDEAM something")
    answer_box = gr.Textbox(label="Answer")
    retrieved_box = gr.JSON(label="Retrieved Docs")

    input_box.submit(chat, input_box, [answer_box, retrieved_box])

demo.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://84d0050a4985ae3cd5.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://84d0050a4985ae3cd5.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\envs\chatbot\lib\site-packages\gradio\queueing.py", line 759, in process_events
#     response = await route_utils.call_process_api(
#   File "C:\Users\user\anaconda3\envs\chatbot\lib\site-packages\gradio\route_utils.py", line 354, in call_process_api
#     output = await app.get_blocks().process_api(
#   File "C:\Users\user\anaconda3\envs\chatbot\lib\site-packages\gradio\blocks.py", line 2116, in process_api
#     result = await self.call_function(
#   File "C:\Users\user\anaconda3\envs\chatbot\lib\site-packages\gradio\blocks.py", line 1623, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#   File "C:\Users\user\anaconda3\envs\chatbot\lib\site-packages\anyio\to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#   File "C:\Users\user\anaconda3\envs\chatbot\lib\site-packages\anyio\_backends\_asyncio.py", line 2485, in run_sync_in_worker_thread
#     return await future
#   File "C:\Users\user\anaconda3\envs\chatbot\lib\site-packages\anyio\_backends\_asyncio.py", line 976, in run
#     result = context.run(func, *args)
#   File "C:\Users\user\anaconda3\envs\chatbot\lib\site-packages\gradio\utils.py", line 915, in wrapper
#     response = f(*args, **kwargs)
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_30680\3130836405.py", line 8, in chat
#     result = process_query(message, debug=True, session_id=session_id)
#   File "C:\Users\user\chatbot_postgresql_test\app\chat\chat_service.py", line 65, in process_query
#     save_review_question(question, reason="weak_answer")
#   File "C:\Users\user\chatbot_postgresql_test\app\database\history.py", line 21, in save_review_question
#     cursor.execute("""
# psycopg2.errors.UndefinedColumn: column "question" of relation "review_questions" does not exist
# LINE 2:         INSERT INTO review_questions (question, reason)
#                                               ^
